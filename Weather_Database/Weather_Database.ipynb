# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from config import weather_api_key
from datetime import datetime
import requests
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify thenearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 776

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Make a 'Get' request for the city weather to check good response.
city_weather = requests.get(url)
city_weather
# Out:
# <Response [400]>

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval        ")
print("--------------------------------")

# Create Counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_min_temp = city_weather["main"]["temp_min"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descr = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Min Temp": city_min_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_descr,
                          "Country": city_country,
                          "Date": city_date})
       
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 1 | huicheng
# Processing Record 2 of Set 1 | brae
# Processing Record 3 of Set 1 | urumqi
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 1 | paamiut
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | ozernovskiy
# Processing Record 9 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | esperance
# Processing Record 12 of Set 1 | walvis bay
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | tateyama
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | qasigiannguit
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | cabo rojo
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | stepnyak
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | lagoa
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | khandyga
# Processing Record 29 of Set 1 | sept-iles
# Processing Record 30 of Set 1 | novaya igirma
# Processing Record 31 of Set 1 | cherskiy
# Processing Record 32 of Set 1 | tazovskiy
# Processing Record 33 of Set 1 | tinskoy
# Processing Record 34 of Set 1 | nadym
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | shanghai
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | naze
# Processing Record 40 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 1 | geraldton
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | bereda
# Processing Record 45 of Set 1 | qaqortoq
# Processing Record 46 of Set 1 | yar-sale
# Processing Record 47 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 1 | andevoranto
# City not found. Skipping...
# Processing Record 49 of Set 1 | grand gaube
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 1 of Set 2 | hasaki
# Processing Record 2 of Set 2 | raga
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | cabo san lucas
# Processing Record 5 of Set 2 | meulaboh
# Processing Record 6 of Set 2 | viedma
# Processing Record 7 of Set 2 | patrocinio
# Processing Record 8 of Set 2 | eldorado
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | mafinga
# Processing Record 11 of Set 2 | bredasdorp
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | abalak
# Processing Record 14 of Set 2 | puerto ayora
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | hami
# Processing Record 17 of Set 2 | solovetskiy
# City not found. Skipping...
# Processing Record 18 of Set 2 | tasiilaq
# Processing Record 19 of Set 2 | cape town
# Processing Record 20 of Set 2 | hithadhoo
# Processing Record 21 of Set 2 | fare
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | sabang
# Processing Record 24 of Set 2 | maymanak
# City not found. Skipping...
# Processing Record 25 of Set 2 | provideniya
# Processing Record 26 of Set 2 | pevek
# Processing Record 27 of Set 2 | boa vista
# Processing Record 28 of Set 2 | kichera
# Processing Record 29 of Set 2 | novyy urengoy
# Processing Record 30 of Set 2 | noumea
# Processing Record 31 of Set 2 | haapu
# City not found. Skipping...
# Processing Record 32 of Set 2 | ludvika
# Processing Record 33 of Set 2 | lisakovsk
# Processing Record 34 of Set 2 | sao jose da coroa grande
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | bambous virieux
# Processing Record 37 of Set 2 | haines junction
# Processing Record 38 of Set 2 | chama
# Processing Record 39 of Set 2 | dudinka
# Processing Record 40 of Set 2 | nikolskoye
# Processing Record 41 of Set 2 | young
# Processing Record 42 of Set 2 | biograd na moru
# Processing Record 43 of Set 2 | jucas
# Processing Record 44 of Set 2 | ostrovnoy
# Processing Record 45 of Set 2 | thompson
# Processing Record 46 of Set 2 | gap
# Processing Record 47 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | ahipara
# Processing Record 50 of Set 2 | ancud
# Processing Record 1 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 3 | charleville-mezieres
# Processing Record 3 of Set 3 | luderitz
# Processing Record 4 of Set 3 | cayenne
# Processing Record 5 of Set 3 | along
# Processing Record 6 of Set 3 | polis
# Processing Record 7 of Set 3 | saskylakh
# Processing Record 8 of Set 3 | birao
# Processing Record 9 of Set 3 | arman
# Processing Record 10 of Set 3 | muros
# Processing Record 11 of Set 3 | sorland
# Processing Record 12 of Set 3 | ombessa
# Processing Record 13 of Set 3 | la rioja
# Processing Record 14 of Set 3 | nome
# Processing Record 15 of Set 3 | te anau
# Processing Record 16 of Set 3 | conselheiro pena
# Processing Record 17 of Set 3 | nabire
# Processing Record 18 of Set 3 | lucapa
# Processing Record 19 of Set 3 | derzhavinsk
# Processing Record 20 of Set 3 | hilo
# Processing Record 21 of Set 3 | avarua
# Processing Record 22 of Set 3 | cumaribo
# City not found. Skipping...
# Processing Record 23 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 3 | cockburn town
# Processing Record 25 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 3 | les escoumins
# Processing Record 27 of Set 3 | kavaratti
# Processing Record 28 of Set 3 | lae
# Processing Record 29 of Set 3 | sao joao da barra
# Processing Record 30 of Set 3 | georgetown
# Processing Record 31 of Set 3 | tibu
# Processing Record 32 of Set 3 | mount gambier
# Processing Record 33 of Set 3 | port blair
# Processing Record 34 of Set 3 | tukums
# Processing Record 35 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 3 | igrim
# Processing Record 37 of Set 3 | norman wells
# Processing Record 38 of Set 3 | pemangkat
# Processing Record 39 of Set 3 | lasa
# Processing Record 40 of Set 3 | edd
# Processing Record 41 of Set 3 | santa maria do suacui
# Processing Record 42 of Set 3 | khani
# Processing Record 43 of Set 3 | zeya
# Processing Record 44 of Set 3 | rock sound
# Processing Record 45 of Set 3 | namatanai
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | cartagena
# Processing Record 48 of Set 3 | erenhot
# Processing Record 49 of Set 3 | clyde river
# Processing Record 50 of Set 3 | touros
# Processing Record 1 of Set 4 | namibe
# Processing Record 2 of Set 4 | uvalde
# Processing Record 3 of Set 4 | kondagaon
# Processing Record 4 of Set 4 | bengkulu
# Processing Record 5 of Set 4 | chumikan
# Processing Record 6 of Set 4 | yorosso
# Processing Record 7 of Set 4 | hambantota
# Processing Record 8 of Set 4 | victor harbor
# Processing Record 9 of Set 4 | berlevag
# Processing Record 10 of Set 4 | iqaluit
# Processing Record 11 of Set 4 | dalianwan
# Processing Record 12 of Set 4 | charlestown
# Processing Record 13 of Set 4 | xuddur
# Processing Record 14 of Set 4 | phangnga
# Processing Record 15 of Set 4 | fort nelson
# Processing Record 16 of Set 4 | tigil
# Processing Record 17 of Set 4 | inirida
# Processing Record 18 of Set 4 | victoria
# Processing Record 19 of Set 4 | pocone
# Processing Record 20 of Set 4 | ramsgate
# Processing Record 21 of Set 4 | aykhal
# Processing Record 22 of Set 4 | itoman
# Processing Record 23 of Set 4 | san andres
# Processing Record 24 of Set 4 | honiara
# Processing Record 25 of Set 4 | tyumen
# Processing Record 26 of Set 4 | terekli-mekteb
# Processing Record 27 of Set 4 | hastings
# Processing Record 28 of Set 4 | chokurdakh
# Processing Record 29 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 4 | araucaria
# Processing Record 31 of Set 4 | nantucket
# Processing Record 32 of Set 4 | fort-shevchenko
# Processing Record 33 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 4 | shar
# Processing Record 35 of Set 4 | butaritari
# Processing Record 36 of Set 4 | alihe
# Processing Record 37 of Set 4 | trairi
# Processing Record 38 of Set 4 | pisco
# Processing Record 39 of Set 4 | flinders
# Processing Record 40 of Set 4 | charters towers
# Processing Record 41 of Set 4 | egvekinot
# Processing Record 42 of Set 4 | zvishavane
# Processing Record 43 of Set 4 | buraydah
# Processing Record 44 of Set 4 | nemuro
# Processing Record 45 of Set 4 | laguna beach
# Processing Record 46 of Set 4 | santa fe
# Processing Record 47 of Set 4 | santa cruz
# Processing Record 48 of Set 4 | fonte boa
# Processing Record 49 of Set 4 | port hardy
# Processing Record 50 of Set 4 | mahebourg
# Processing Record 1 of Set 5 | udachnyy
# Processing Record 2 of Set 5 | severo-kurilsk
# Processing Record 3 of Set 5 | talnakh
# Processing Record 4 of Set 5 | sur
# Processing Record 5 of Set 5 | eten
# Processing Record 6 of Set 5 | la ronge
# Processing Record 7 of Set 5 | leh
# Processing Record 8 of Set 5 | camalu
# Processing Record 9 of Set 5 | nogales
# Processing Record 10 of Set 5 | belyy yar
# Processing Record 11 of Set 5 | mankato
# Processing Record 12 of Set 5 | manaure
# Processing Record 13 of Set 5 | oksfjord
# Processing Record 14 of Set 5 | wuda
# Processing Record 15 of Set 5 | moose factory
# Processing Record 16 of Set 5 | khatanga
# Processing Record 17 of Set 5 | laguna
# Processing Record 18 of Set 5 | makakilo city
# Processing Record 19 of Set 5 | salinopolis
# Processing Record 20 of Set 5 | buchanan
# Processing Record 21 of Set 5 | north marysville
# City not found. Skipping...
# Processing Record 22 of Set 5 | lebu
# Processing Record 23 of Set 5 | mpanda
# Processing Record 24 of Set 5 | nizhneudinsk
# Processing Record 25 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 26 of Set 5 | san francisco
# Processing Record 27 of Set 5 | gornopravdinsk
# Processing Record 28 of Set 5 | kaitangata
# Processing Record 29 of Set 5 | lekoni
# Processing Record 30 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 5 | palu
# Processing Record 32 of Set 5 | stavrovo
# Processing Record 33 of Set 5 | catamarca
# Processing Record 34 of Set 5 | tabou
# Processing Record 35 of Set 5 | lompoc
# Processing Record 36 of Set 5 | belur
# Processing Record 37 of Set 5 | carnarvon
# Processing Record 38 of Set 5 | liverpool
# Processing Record 39 of Set 5 | mondlo
# Processing Record 40 of Set 5 | klaksvik
# Processing Record 41 of Set 5 | mokrous
# Processing Record 42 of Set 5 | kungsbacka
# Processing Record 43 of Set 5 | alice springs
# Processing Record 44 of Set 5 | worland
# Processing Record 45 of Set 5 | dingle
# Processing Record 46 of Set 5 | myingyan
# Processing Record 47 of Set 5 | kroonstad
# Processing Record 48 of Set 5 | waipawa
# Processing Record 49 of Set 5 | la union
# Processing Record 50 of Set 5 | dzilam gonzalez
# Processing Record 1 of Set 6 | east london
# Processing Record 2 of Set 6 | ambilobe
# Processing Record 3 of Set 6 | tiksi
# Processing Record 4 of Set 6 | doha
# Processing Record 5 of Set 6 | vanimo
# Processing Record 6 of Set 6 | snezhnogorsk
# Processing Record 7 of Set 6 | wad madani
# Processing Record 8 of Set 6 | port alfred
# Processing Record 9 of Set 6 | qinzhou
# Processing Record 10 of Set 6 | mar del plata
# Processing Record 11 of Set 6 | kruisfontein
# Processing Record 12 of Set 6 | lorengau
# Processing Record 13 of Set 6 | udon thani
# Processing Record 14 of Set 6 | oktyabrskoye
# Processing Record 15 of Set 6 | comodoro rivadavia
# Processing Record 16 of Set 6 | riberalta
# Processing Record 17 of Set 6 | radcliff
# Processing Record 18 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 6 | north ridgeville
# Processing Record 20 of Set 6 | kutum
# Processing Record 21 of Set 6 | ramos arizpe
# Processing Record 22 of Set 6 | bonavista
# Processing Record 23 of Set 6 | seymchan
# Processing Record 24 of Set 6 | tabas
# Processing Record 25 of Set 6 | kota kinabalu
# Processing Record 26 of Set 6 | merrill
# Processing Record 27 of Set 6 | chimbote
# Processing Record 28 of Set 6 | grindavik
# Processing Record 29 of Set 6 | nanortalik
# Processing Record 30 of Set 6 | sullana
# Processing Record 31 of Set 6 | roald
# Processing Record 32 of Set 6 | maralal
# Processing Record 33 of Set 6 | ixtapa
# Processing Record 34 of Set 6 | mahibadhoo
# Processing Record 35 of Set 6 | revda
# Processing Record 36 of Set 6 | eureka
# Processing Record 37 of Set 6 | challapata
# Processing Record 38 of Set 6 | kristiinankaupunki
# Processing Record 39 of Set 6 | richards bay
# Processing Record 40 of Set 6 | concordia
# Processing Record 41 of Set 6 | urengoy
# Processing Record 42 of Set 6 | a
# City not found. Skipping...
# Processing Record 43 of Set 6 | kungurtug
# Processing Record 44 of Set 6 | taltal
# Processing Record 45 of Set 6 | filadelfia
# Processing Record 46 of Set 6 | codrington
# Processing Record 47 of Set 6 | westport
# Processing Record 48 of Set 6 | necochea
# Processing Record 49 of Set 6 | winneba
# Processing Record 50 of Set 6 | mayo
# Processing Record 1 of Set 7 | san patricio
# Processing Record 2 of Set 7 | ilulissat
# Processing Record 3 of Set 7 | mount pleasant
# Processing Record 4 of Set 7 | rabo de peixe
# Processing Record 5 of Set 7 | kaseda
# Processing Record 6 of Set 7 | saint-michel-des-saints
# Processing Record 7 of Set 7 | montepuez
# Processing Record 8 of Set 7 | luganville
# Processing Record 9 of Set 7 | tuktoyaktuk
# Processing Record 10 of Set 7 | taikang
# Processing Record 11 of Set 7 | wanning
# Processing Record 12 of Set 7 | sokoni
# Processing Record 13 of Set 7 | airai
# Processing Record 14 of Set 7 | saint-joseph
# Processing Record 15 of Set 7 | uyuni
# Processing Record 16 of Set 7 | wilmington
# Processing Record 17 of Set 7 | takoradi
# Processing Record 18 of Set 7 | hualmay
# Processing Record 19 of Set 7 | pueblo nuevo
# Processing Record 20 of Set 7 | gangapur
# Processing Record 21 of Set 7 | rodrigues alves
# Processing Record 22 of Set 7 | darhan
# Processing Record 23 of Set 7 | cabedelo
# Processing Record 24 of Set 7 | kattivakkam
# Processing Record 25 of Set 7 | san cristobal
# Processing Record 26 of Set 7 | roanoke rapids
# Processing Record 27 of Set 7 | nicoya
# Processing Record 28 of Set 7 | acapulco
# Processing Record 29 of Set 7 | saldanha
# Processing Record 30 of Set 7 | corinto
# Processing Record 31 of Set 7 | kahului
# Processing Record 32 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 7 | saint george
# Processing Record 34 of Set 7 | bac giang
# Processing Record 35 of Set 7 | sobolevo
# Processing Record 36 of Set 7 | vilyuysk
# Processing Record 37 of Set 7 | boden
# Processing Record 38 of Set 7 | ponta do sol
# Processing Record 39 of Set 7 | aksu
# Processing Record 40 of Set 7 | maloy
# Processing Record 41 of Set 7 | portland
# Processing Record 42 of Set 7 | souillac
# Processing Record 43 of Set 7 | morondava
# Processing Record 44 of Set 7 | danilovka
# Processing Record 45 of Set 7 | bonthe
# Processing Record 46 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 7 | beringovskiy
# Processing Record 48 of Set 7 | yefremov
# Processing Record 49 of Set 7 | ceres
# Processing Record 50 of Set 7 | lata
# Processing Record 1 of Set 8 | kavieng
# Processing Record 2 of Set 8 | coihaique
# Processing Record 3 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 8 | chiredzi
# Processing Record 5 of Set 8 | weihe
# Processing Record 6 of Set 8 | batemans bay
# Processing Record 7 of Set 8 | vestmannaeyjar
# Processing Record 8 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 8 | bathsheba
# Processing Record 10 of Set 8 | upernavik
# Processing Record 11 of Set 8 | constancia
# Processing Record 12 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 8 | marshall
# Processing Record 14 of Set 8 | jaszladany
# Processing Record 15 of Set 8 | salamiyah
# Processing Record 16 of Set 8 | trapani
# Processing Record 17 of Set 8 | vila franca do campo
# Processing Record 18 of Set 8 | lavrentiya
# Processing Record 19 of Set 8 | yarkovo
# Processing Record 20 of Set 8 | ahuimanu
# Processing Record 21 of Set 8 | san clemente
# Processing Record 22 of Set 8 | porto novo
# Processing Record 23 of Set 8 | tecoanapa
# Processing Record 24 of Set 8 | jieshi
# Processing Record 25 of Set 8 | wuwei
# Processing Record 26 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 8 | chaman
# Processing Record 28 of Set 8 | kiruna
# Processing Record 29 of Set 8 | port-cartier
# Processing Record 30 of Set 8 | sola
# Processing Record 31 of Set 8 | great yarmouth
# Processing Record 32 of Set 8 | porto nacional
# Processing Record 33 of Set 8 | maxixe
# Processing Record 34 of Set 8 | preobrazheniye
# Processing Record 35 of Set 8 | mazatlan
# Processing Record 36 of Set 8 | atar
# Processing Record 37 of Set 8 | gummersbach
# Processing Record 38 of Set 8 | azimur
# City not found. Skipping...
# Processing Record 39 of Set 8 | sovetskiy
# Processing Record 40 of Set 8 | san pedro
# Processing Record 41 of Set 8 | kaikalur
# Processing Record 42 of Set 8 | caraballeda
# Processing Record 43 of Set 8 | manakara
# Processing Record 44 of Set 8 | langsa
# Processing Record 45 of Set 8 | hamilton
# Processing Record 46 of Set 8 | belmonte
# Processing Record 47 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 49 of Set 8 | progreso
# Processing Record 50 of Set 8 | aksha
# Processing Record 1 of Set 9 | puerto del rosario
# Processing Record 2 of Set 9 | aklavik
# Processing Record 3 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 9 | shubarkuduk
# Processing Record 5 of Set 9 | kumylzhenskaya
# Processing Record 6 of Set 9 | fernley
# Processing Record 7 of Set 9 | komsomolskiy
# Processing Record 8 of Set 9 | taoudenni
# Processing Record 9 of Set 9 | idrinskoye
# Processing Record 10 of Set 9 | saint anthony
# Processing Record 11 of Set 9 | sydney
# Processing Record 12 of Set 9 | skole
# Processing Record 13 of Set 9 | sao gabriel da cachoeira
# Processing Record 14 of Set 9 | sisimiut
# Processing Record 15 of Set 9 | tobol
# Processing Record 16 of Set 9 | ileza
# Processing Record 17 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 9 | usinsk
# Processing Record 19 of Set 9 | villa bruzual
# Processing Record 20 of Set 9 | guerrero negro
# Processing Record 21 of Set 9 | caravelas
# Processing Record 22 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 9 | umm lajj
# Processing Record 24 of Set 9 | calama
# Processing Record 25 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 26 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 9 | aswan
# Processing Record 28 of Set 9 | chuy
# Processing Record 29 of Set 9 | sechura
# Processing Record 30 of Set 9 | constantine
# Processing Record 31 of Set 9 | nioro
# Processing Record 32 of Set 9 | jacareacanga
# Processing Record 33 of Set 9 | hokitika
# Processing Record 34 of Set 9 | znamenskoye
# Processing Record 35 of Set 9 | hobyo
# Processing Record 36 of Set 9 | boueni
# Processing Record 37 of Set 9 | high level
# Processing Record 38 of Set 9 | faanui
# Processing Record 39 of Set 9 | oudtshoorn
# Processing Record 40 of Set 9 | ust-nera
# Processing Record 41 of Set 9 | mehamn
# Processing Record 42 of Set 9 | kamenka
# Processing Record 43 of Set 9 | falun
# Processing Record 44 of Set 9 | constitucion
# Processing Record 45 of Set 9 | bantou
# Processing Record 46 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 9 | the valley
# Processing Record 48 of Set 9 | leningradskiy
# Processing Record 49 of Set 9 | teguise
# Processing Record 50 of Set 9 | maneadero
# Processing Record 1 of Set 10 | mayumba
# Processing Record 2 of Set 10 | shanting
# Processing Record 3 of Set 10 | alofi
# Processing Record 4 of Set 10 | villarrica
# Processing Record 5 of Set 10 | narsaq
# Processing Record 6 of Set 10 | yanchukan
# City not found. Skipping...
# Processing Record 7 of Set 10 | maceio
# Processing Record 8 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 10 | quatre cocos
# Processing Record 10 of Set 10 | rundu
# Processing Record 11 of Set 10 | shunyi
# Processing Record 12 of Set 10 | puerto ayacucho
# Processing Record 13 of Set 10 | amga
# Processing Record 14 of Set 10 | jarjis
# City not found. Skipping...
# Processing Record 15 of Set 10 | warri
# Processing Record 16 of Set 10 | ketchikan
# Processing Record 17 of Set 10 | mareeba
# Processing Record 18 of Set 10 | senanga
# Processing Record 19 of Set 10 | northam
# Processing Record 20 of Set 10 | noboribetsu
# Processing Record 21 of Set 10 | vostok
# Processing Record 22 of Set 10 | el fuerte
# Processing Record 23 of Set 10 | havre-saint-pierre
# Processing Record 24 of Set 10 | valleyview
# Processing Record 25 of Set 10 | homer
# Processing Record 26 of Set 10 | padang
# Processing Record 27 of Set 10 | nijar
# Processing Record 28 of Set 10 | vardo
# Processing Record 29 of Set 10 | asau
# Processing Record 30 of Set 10 | liozon
# Processing Record 31 of Set 10 | visby
# Processing Record 32 of Set 10 | banda aceh
# Processing Record 33 of Set 10 | santo domingo
# Processing Record 34 of Set 10 | kikwit
# Processing Record 35 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 36 of Set 10 | pangnirtung
# Processing Record 37 of Set 10 | gannan
# Processing Record 38 of Set 10 | kefamenanu
# Processing Record 39 of Set 10 | forst
# Processing Record 40 of Set 10 | trzcianka
# Processing Record 41 of Set 10 | letlhakane
# Processing Record 42 of Set 10 | corlu
# Processing Record 43 of Set 10 | bud
# Processing Record 44 of Set 10 | kenai
# Processing Record 45 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 10 | asfi
# Processing Record 48 of Set 10 | katsuura
# Processing Record 49 of Set 10 | port hedland
# Processing Record 50 of Set 10 | susanville
# Processing Record 1 of Set 11 | mugur-aksy
# Processing Record 2 of Set 11 | alamogordo
# Processing Record 3 of Set 11 | the pas
# Processing Record 4 of Set 11 | arlit
# Processing Record 5 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 11 | galle
# Processing Record 7 of Set 11 | kapoeta
# Processing Record 8 of Set 11 | buala
# Processing Record 9 of Set 11 | fountain
# Processing Record 10 of Set 11 | kununurra
# Processing Record 11 of Set 11 | samarai
# Processing Record 12 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 13 of Set 11 | zuwarah
# Processing Record 14 of Set 11 | harper
# Processing Record 15 of Set 11 | warangal
# Processing Record 16 of Set 11 | vysokogornyy
# Processing Record 17 of Set 11 | aitape
# Processing Record 18 of Set 11 | donskoye
# Processing Record 19 of Set 11 | christchurch
# Processing Record 20 of Set 11 | kulhudhuffushi
# Processing Record 21 of Set 11 | labuhan
# Processing Record 22 of Set 11 | amapa
# Processing Record 23 of Set 11 | verkhnetulomskiy
# Processing Record 24 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 11 | farsund
# Processing Record 26 of Set 11 | okha
# Processing Record 27 of Set 11 | torbay
# Processing Record 28 of Set 11 | pokhara
# Processing Record 29 of Set 11 | muriti
# Processing Record 30 of Set 11 | cairns
# Processing Record 31 of Set 11 | carbonia
# Processing Record 32 of Set 11 | orel-izumrud
# Processing Record 33 of Set 11 | adrar
# Processing Record 34 of Set 11 | townsville
# Processing Record 35 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 11 | mackay
# Processing Record 37 of Set 11 | madras
# Processing Record 38 of Set 11 | saint-denis
# Processing Record 39 of Set 11 | brekstad
# Processing Record 40 of Set 11 | wang noi
# Processing Record 41 of Set 11 | palasa
# Processing Record 42 of Set 11 | polson
# Processing Record 43 of Set 11 | weihai
# Processing Record 44 of Set 11 | yangambi
# Processing Record 45 of Set 11 | karamay
# City not found. Skipping...
# Processing Record 46 of Set 11 | fairbanks
# Processing Record 47 of Set 11 | kindu
# Processing Record 48 of Set 11 | mulhouse
# Processing Record 49 of Set 11 | sinop
# Processing Record 50 of Set 11 | sulangan
# Processing Record 1 of Set 12 | novaya lyalya
# Processing Record 2 of Set 12 | mitu
# Processing Record 3 of Set 12 | nouadhibou
# Processing Record 4 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 5 of Set 12 | canutama
# Processing Record 6 of Set 12 | gamba
# Processing Record 7 of Set 12 | ojinaga
# Processing Record 8 of Set 12 | gornyy
# Processing Record 9 of Set 12 | nyurba
# Processing Record 10 of Set 12 | isangel
# Processing Record 11 of Set 12 | kroya
# Processing Record 12 of Set 12 | tornio
# Processing Record 13 of Set 12 | platanos
# Processing Record 14 of Set 12 | itacare
# Processing Record 15 of Set 12 | talcher
# Processing Record 16 of Set 12 | helong
# Processing Record 17 of Set 12 | evensk
# Processing Record 18 of Set 12 | antalaha
# Processing Record 19 of Set 12 | vao
# Processing Record 20 of Set 12 | tuatapere
# Processing Record 21 of Set 12 | longyearbyen
# Processing Record 22 of Set 12 | kirakira
# Processing Record 23 of Set 12 | margate
# Processing Record 24 of Set 12 | salme
# Processing Record 25 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 26 of Set 12 | moerai
# Processing Record 27 of Set 12 | belousovka
# Processing Record 28 of Set 12 | zachagansk
# City not found. Skipping...
# Processing Record 29 of Set 12 | lamar
# Processing Record 30 of Set 12 | okhotsk
# Processing Record 31 of Set 12 | west bay
# Processing Record 32 of Set 12 | cidreira
# Processing Record 33 of Set 12 | pringsewu
# Processing Record 34 of Set 12 | olafsvik
# Processing Record 35 of Set 12 | houma
# Processing Record 36 of Set 12 | kampene
# Processing Record 37 of Set 12 | gat
# Processing Record 38 of Set 12 | kayes
# Processing Record 39 of Set 12 | manado
# Processing Record 40 of Set 12 | huainan
# Processing Record 41 of Set 12 | mount isa
# Processing Record 42 of Set 12 | galesong
# Processing Record 43 of Set 12 | atambua
# Processing Record 44 of Set 12 | nara
# Processing Record 45 of Set 12 | sao gabriel
# Processing Record 46 of Set 12 | mangrol
# Processing Record 47 of Set 12 | oranjemund
# Processing Record 48 of Set 12 | denpasar
# Processing Record 49 of Set 12 | sun city west
# Processing Record 50 of Set 12 | killybegs
# Processing Record 1 of Set 13 | goksun
# Processing Record 2 of Set 13 | todos santos
# Processing Record 3 of Set 13 | henties bay
# Processing Record 4 of Set 13 | laukaa
# Processing Record 5 of Set 13 | nushki
# Processing Record 6 of Set 13 | rawah
# Processing Record 7 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 8 of Set 13 | funadhoo
# Processing Record 9 of Set 13 | roma
# Processing Record 10 of Set 13 | mudgee
# Processing Record 11 of Set 13 | likasi
# Processing Record 12 of Set 13 | lucea
# Processing Record 13 of Set 13 | zhigalovo
# Processing Record 14 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 15 of Set 13 | balykshi
# Processing Record 16 of Set 13 | fortuna
# Processing Record 17 of Set 13 | cozumel
# Processing Record 18 of Set 13 | cananea
# Processing Record 19 of Set 13 | zhigansk
# Processing Record 20 of Set 13 | mogadishu
# Processing Record 21 of Set 13 | humaita
# Processing Record 22 of Set 13 | bairiki
# Processing Record 23 of Set 13 | dalbandin
# Processing Record 24 of Set 13 | krasnoselkup
# Processing Record 25 of Set 13 | shimoda
# Processing Record 26 of Set 13 | benguela
# Processing Record 27 of Set 13 | rawson
# Processing Record 28 of Set 13 | bella union
# Processing Record 29 of Set 13 | marawi
# Processing Record 30 of Set 13 | avera
# Processing Record 31 of Set 13 | toyooka
# Processing Record 32 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 13 | kandrian
# Processing Record 34 of Set 13 | ferrol
# Processing Record 35 of Set 13 | jiuquan
# Processing Record 36 of Set 13 | lakeside
# Processing Record 37 of Set 13 | anadyr
# Processing Record 38 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 39 of Set 13 | honggang
# Processing Record 40 of Set 13 | maraa
# Processing Record 41 of Set 13 | tura
# Processing Record 42 of Set 13 | zelenoborsk
# Processing Record 43 of Set 13 | superior
# Processing Record 44 of Set 13 | kinsale
# Processing Record 45 of Set 13 | anchorage
# Processing Record 46 of Set 13 | san luis
# Processing Record 47 of Set 13 | viseu
# Processing Record 48 of Set 13 | sinaloa
# Processing Record 49 of Set 13 | champerico
# Processing Record 50 of Set 13 | north bend
# Processing Record 1 of Set 14 | vozhega
# Processing Record 2 of Set 14 | keokuk
# Processing Record 3 of Set 14 | nokha
# Processing Record 4 of Set 14 | baykit
# Processing Record 5 of Set 14 | marrakesh
# Processing Record 6 of Set 14 | bambanglipuro
# Processing Record 7 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 8 of Set 14 | najran
# Processing Record 9 of Set 14 | cap malheureux
# Processing Record 10 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 11 of Set 14 | alexandria
# Processing Record 12 of Set 14 | pandan
# Processing Record 13 of Set 14 | panaba
# Processing Record 14 of Set 14 | shelburne
# Processing Record 15 of Set 14 | hailar
# Processing Record 16 of Set 14 | lakhdenpokhya
# Processing Record 17 of Set 14 | merauke
# Processing Record 18 of Set 14 | verkhnyaya inta
# Processing Record 19 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 14 | rizhao
# Processing Record 21 of Set 14 | bergen
# Processing Record 22 of Set 14 | balma
# Processing Record 23 of Set 14 | liku
# Processing Record 24 of Set 14 | grua
# Processing Record 25 of Set 14 | turayf
# Processing Record 26 of Set 14 | atasu
# Processing Record 27 of Set 14 | bagli
# Processing Record 28 of Set 14 | conceicao do araguaia
# Processing Record 29 of Set 14 | hirara
# Processing Record 30 of Set 14 | whyalla
# Processing Record 31 of Set 14 | salgar
# Processing Record 32 of Set 14 | lhuntshi
# City not found. Skipping...
# Processing Record 33 of Set 14 | bilma
# Processing Record 34 of Set 14 | barentu
# Processing Record 35 of Set 14 | lander
# Processing Record 36 of Set 14 | dulce nombre de culmi
# Processing Record 37 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 14 | olinda
# Processing Record 39 of Set 14 | mantua
# Processing Record 40 of Set 14 | baraboo
# Processing Record 41 of Set 14 | colares
# Processing Record 42 of Set 14 | bago
# Processing Record 43 of Set 14 | oswego
# Processing Record 44 of Set 14 | dickinson
# Processing Record 45 of Set 14 | vilhena
# Processing Record 46 of Set 14 | port-gentil
# Processing Record 47 of Set 14 | ust-omchug
# Processing Record 48 of Set 14 | tirumullaivasal
# Processing Record 49 of Set 14 | nefteyugansk
# Processing Record 50 of Set 14 | tillabery
# City not found. Skipping...
# Processing Record 1 of Set 15 | lanzhou
# Processing Record 2 of Set 15 | busilac
# Processing Record 3 of Set 15 | sukumo
# Processing Record 4 of Set 15 | baffa
# Processing Record 5 of Set 15 | shizunai
# Processing Record 6 of Set 15 | sinnamary
# Processing Record 7 of Set 15 | marovoay
# Processing Record 8 of Set 15 | liepaja
# Processing Record 9 of Set 15 | port keats
# Processing Record 10 of Set 15 | yumen
# Processing Record 11 of Set 15 | ginir
# Processing Record 12 of Set 15 | pankrushikha
# Processing Record 13 of Set 15 | cienfuegos
# Processing Record 14 of Set 15 | koslan
# Processing Record 15 of Set 15 | lhokseumawe
# Processing Record 16 of Set 15 | casa grande
# Processing Record 17 of Set 15 | deputatskiy
# Processing Record 18 of Set 15 | nauta
# Processing Record 19 of Set 15 | villa juarez
# Processing Record 20 of Set 15 | ushumun
# Processing Record 21 of Set 15 | srednekolymsk
# Processing Record 22 of Set 15 | alugan
# Processing Record 23 of Set 15 | choix
# Processing Record 24 of Set 15 | amboasary
# Processing Record 25 of Set 15 | don sak
# Processing Record 26 of Set 15 | bossembele
# City not found. Skipping...
# Processing Record 27 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 28 of Set 15 | winfield
# Processing Record 29 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 30 of Set 15 | verkhnyaya tura
# Processing Record 31 of Set 15 | kismayo
# Processing Record 32 of Set 15 | solsvik
# City not found. Skipping...
# Processing Record 33 of Set 15 | prigorodka
# Processing Record 34 of Set 15 | varhaug
# Processing Record 35 of Set 15 | bilibino
# Processing Record 36 of Set 15 | novikovo
# Processing Record 37 of Set 15 | whitianga
# Processing Record 38 of Set 15 | malyye derbety
# Processing Record 39 of Set 15 | kawambwa
# Processing Record 40 of Set 15 | ponta delgada
# Processing Record 41 of Set 15 | mitsamiouli
# Processing Record 42 of Set 15 | camaqua
# Processing Record 43 of Set 15 | oussouye
# Processing Record 44 of Set 15 | quelimane
# Processing Record 45 of Set 15 | mana
# Processing Record 46 of Set 15 | uruzgan
# Processing Record 47 of Set 15 | ilebo
# Processing Record 48 of Set 15 | nsanje
# Processing Record 49 of Set 15 | pitimbu
# Processing Record 50 of Set 15 | ocos
# Processing Record 1 of Set 16 | poso
# Processing Record 2 of Set 16 | manavalakurichi
# Processing Record 3 of Set 16 | ayagoz
# Processing Record 4 of Set 16 | ponnani
# Processing Record 5 of Set 16 | nikel
# Processing Record 6 of Set 16 | ordu
# Processing Record 7 of Set 16 | santa luzia
# Processing Record 8 of Set 16 | chambarak
# Processing Record 9 of Set 16 | kyren
# Processing Record 10 of Set 16 | balikpapan
# Processing Record 11 of Set 16 | saint-augustin
# Processing Record 12 of Set 16 | bandarbeyla
# Processing Record 13 of Set 16 | lima
# Processing Record 14 of Set 16 | kunhegyes
# Processing Record 15 of Set 16 | qujing
# Processing Record 16 of Set 16 | perdika
# Processing Record 17 of Set 16 | el wasta
# City not found. Skipping...
# Processing Record 18 of Set 16 | salalah
# Processing Record 19 of Set 16 | rio gallegos
# Processing Record 20 of Set 16 | tahe
# Processing Record 21 of Set 16 | uglegorsk
# Processing Record 22 of Set 16 | yulara
# Processing Record 23 of Set 16 | yarmouth
# Processing Record 24 of Set 16 | abu dhabi
# Processing Record 25 of Set 16 | ola
# Processing Record 26 of Set 16 | huarmey
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Huicheng  23.0385  116.2899     69.80        60           0        2.24
# 1         Brae  60.3964   -1.3530     44.60        87         100       12.66
# 2       Urumqi  43.8010   87.6005     60.80        39           0       11.18
# 3        Vaini -21.2000 -175.2000     80.60        78          40        9.22
# 4      Paamiut  61.9940  -49.6678     27.43        75         100       12.84
# 5      Rikitea -23.1203 -134.9692     77.92        75          11        6.91
# 6  Ozernovskiy  51.5000  156.5167     37.49        80         100       17.29
# 7       Atuona  -9.8000 -139.0333     80.28        79          18       18.79
# 8    Esperance -33.8667  121.9000     59.00        82          67        8.05
# 9   Walvis Bay -22.9575   14.5053     86.00        41          25        8.99
#
#         Description Country                 Date
# 0         clear sky      CN  2021-04-19 00:54:43
# 1   overcast clouds      GB  2021-04-19 00:53:52
# 2         clear sky      CN  2021-04-19 00:53:55
# 3  scattered clouds      TO  2021-04-19 00:53:20
# 4        light snow      GL  2021-04-19 00:54:44
# 5        few clouds      PF  2021-04-19 00:52:59
# 6   overcast clouds      RU  2021-04-19 00:54:44
# 7        few clouds      PF  2021-04-19 00:53:26
# 8     broken clouds      AU  2021-04-19 00:53:47
# 9  scattered clouds      NA  2021-04-19 00:54:45

# %%
# reorder columns in DataFrame
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Huicheng      CN  23.0385  116.2899     69.80        60           0
# 1         Brae      GB  60.3964   -1.3530     44.60        87         100
# 2       Urumqi      CN  43.8010   87.6005     60.80        39           0
# 3        Vaini      TO -21.2000 -175.2000     80.60        78          40
# 4      Paamiut      GL  61.9940  -49.6678     27.43        75         100
# 5      Rikitea      PF -23.1203 -134.9692     77.92        75          11
# 6  Ozernovskiy      RU  51.5000  156.5167     37.49        80         100
# 7       Atuona      PF  -9.8000 -139.0333     80.28        79          18
# 8    Esperance      AU -33.8667  121.9000     59.00        82          67
# 9   Walvis Bay      NA -22.9575   14.5053     86.00        41          25
#
#    Wind Speed       Description
# 0        2.24         clear sky
# 1       12.66   overcast clouds
# 2       11.18         clear sky
# 3        9.22  scattered clouds
# 4       12.84        light snow
# 5        6.91        few clouds
# 6       17.29   overcast clouds
# 7       18.79        few clouds
# 8        8.05     broken clouds
# 9        8.99  scattered clouds

# %%
# Create as CSV output
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")  #also changes index column to City_ID instead of blank
